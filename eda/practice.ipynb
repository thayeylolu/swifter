# %%
import pandas as pd

# %%
data = pd.read_csv('../data/aircraft.csv')

# %%
data.head()
# Out:
#   Secondary sanctions risk    Additional Sanctions Information  \
# 0                      NaN    - Subject to SecondarySanctions
# 1                      NaN                                 NaN
# 2                      NaN                                 NaN
# 3                      NaN                                 NaN
# 4                      NaN   - Subject to Secondary Sanctions
#
#   Aircraft Mode S Transponder Code LinkedTo:  \
# 0                              NaN       NaN
# 1                              NaN       NaN
# 2                              NaN       NaN
# 3                              NaN       NaN
# 4                              NaN       NaN
#
#            Aircraft Construction Number  \
# 0   (also called L/N or S/N or F/N) 464
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
# ...
